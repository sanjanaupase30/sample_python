# %% [markdown]
# Aggregate

# %%
import numpy
a=numpy.array([1,2,3])
c=numpy.sum(a)
print(c)
# Out:
# 6

# %%
import numpy
a=numpy.array(['a',True,5])
c=numpy.sum(a)
print(c)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[2], line 3
#       1 import numpy
#       2 a=numpy.array(['a',True,5])
# ----> 3 c=numpy.sum(a)
#       4 print(c)
#
# File <__array_function__ internals>:200, in sum(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:2324, in sum(a, axis, dtype, out, keepdims, initial, where)
#    2321         return out
#    2322     return res
# -> 2324 return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
#    2325                       initial=initial, where=where)
#
# File ~/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83         else:
#      84             return reduction(axis=axis, out=out, **passkwargs)
# ---> 86 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# ...

# %%
import numpy
a=numpy.array([7,,2.9,5])
c=numpy.sum(a)
print(c)
# Out:
#   Cell In[4], line 2
#     a=numpy.array([7,,2.9,5])
#                      ^
# SyntaxError: invalid syntax

# %%
import numpy
a=numpy.array([7,2.9,5])
c=numpy.nansum(a)
print(c)
# Out:
# 14.9
